# %% [markdown]
# ## Pop Culture Code
#
# Here's a fancy picture of what coding is seen as in pop culture...
#
# ![some_generic_code_picture.jpg](attachment:some_generic_code_picture.jpg)

# %% [markdown]
# ***
# ## Reality
# Here's what it actually looks like :

# %%
print("Hello World!")
# Out:
# Hello World!
